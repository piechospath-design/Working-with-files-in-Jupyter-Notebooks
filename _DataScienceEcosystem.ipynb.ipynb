# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
print(" Data Science Tool And Ecosystem")
# Out:
#  Data Science Tool And Ecosystem

# %%
print("In this notebook, Data Science Tools and Ecosystem are summarized by Piecho")
# Out:
# In this notebook, Data Science Tools and Ecosystem are summarized by Piecho

# %%
print("Some of the popular languages that Data Scientists use are:")
programmi = ["Python", "R", "SQL", "Julia", "SAS"]

for p in programmi:
    print(f"- {p}")
# Out:
# Some of the popular languages that Data Scientists use are:
# - Python
# - R
# - SQL
# - Julia
# - SAS

# %% [markdown]
# | Data Science Tool | Description                          |
# |-------------------|--------------------------------------|
# | Python            | Widely used for data analysis & ML   |
# | R                 | Great for statistical computing      |
# | SQL               | Used for querying & managing data    |
# | Julia             | High-performance for numerical work  |
# | SAS               | Popular in business analytics        |

# %% [markdown]
# <h3> Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# <h2> Author </h2>
# Pietro Gareri

# %%
print("This a simple arithmetic expression to mutiply then add integers")
(3*4)+5
# Out:
# This a simple arithmetic expression to mutiply then add integers
# 17

# %%
print("This will convert 200 minutes to hours by diving by 60")
def dividi_200_per_60():
    risultato = 200 / 60
    return risultato

# esempio d'uso
print(dividi_200_per_60())
# Out:
# This will convert 200 minutes to hours by diving by 60
# 3.3333333333333335
